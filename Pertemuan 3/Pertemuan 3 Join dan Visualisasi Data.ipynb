# %% [markdown]
# # **Combining Data**

# %% [markdown]
# Combining data atau menggabungkan data dari beberapa dataframe, beberapa function dasar dari pandas yang dapat kita pakai untuk menggabungkan data adalah:
#
# - merge()
# - join()
# - concat()

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("penguins_size.csv")

# %% [markdown]
# ## Merge

# %% [markdown]
# Function merge digunakan untuk menggabungkan data pada Columns atau indices yang sama

# %%
data1 = data.sample(n=40, random_state=30)
data1["cummulative"] = data['flipper_length_mm']/data['culmen_depth_mm']
data2 = data.sample(n=20, random_state=80)

# %%
print(f"Data 1 Shape = {data1.shape}")
print(f"Data 2 Shape = {data2.shape}")
# Out:
# Data 1 Shape = (40, 8)
# Data 2 Shape = (20, 7)

# %% [markdown]
# ### *Inner Join*

# %% [markdown]
# Inner join merupakan penggabungan dataframe dimana key atau indices dimiliki oleh kedua dataframenya dan menganulir yang tidak sama

# %%
inner_merge = pd.merge(data1, data2)

# %%
inner_merge
# Out:
#   species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Biscoe              35.9             19.2              189.0
# 1  Adelie  Biscoe              35.7             16.9              185.0
# 2  Adelie  Biscoe              42.0             19.5              200.0
#
#    body_mass_g     sex  cummulative
# 0       3800.0  FEMALE     9.843750
# 1       3150.0  FEMALE    10.946746
# 2       4050.0    MALE    10.256410

# %%
inner_merge.shape
# Out:
# (3, 8)

# %% [markdown]
# Dengan menggunakan merge kita juga dapat menggabungkan seluruh dataset tetapi hanya spesifik kolom seperti disini species dan island

# %%
inner_merged_total = pd.merge(data1, data2, on= ['species','island'])

# %%
inner_merged_total
# Out:
#        species  island  culmen_length_mm_x  culmen_depth_mm_x  \
# 0    Chinstrap   Dream                45.5               17.0
# 1    Chinstrap   Dream                45.5               17.0
# 2    Chinstrap   Dream                45.5               17.0
# 3    Chinstrap   Dream                45.5               17.0
# 4    Chinstrap   Dream                46.1               18.2
# ..         ...     ...                 ...                ...
# 201     Adelie  Biscoe                42.0               19.5
# 202     Adelie  Biscoe                42.0               19.5
# 203     Adelie  Biscoe                42.0               19.5
# 204     Adelie   Dream                36.8               18.5
# 205     Adelie   Dream                39.2               21.1
#
#      flipper_length_mm_x  body_mass_g_x   sex_x  cummulative  \
# 0                  196.0         3500.0  FEMALE    11.529412
# 1                  196.0         3500.0  FEMALE    11.529412
# 2                  196.0         3500.0  FEMALE    11.529412
# 3                  196.0         3500.0  FEMALE    11.529412
# 4                  178.0         3250.0  FEMALE     9.780220
# ..                   ...            ...     ...          ...
# 201                200.0         4050.0    MALE    10.256410
# 202                200.0         4050.0    MALE    10.256410
# 203                200.0         4050.0    MALE    10.256410
# 204                193.0         3500.0  FEMALE    10.432432
# 205                196.0         4150.0    MALE     9.289100
#
#      culmen_length_mm_y  culmen_depth_mm_y  flipper_length_mm_y  \
# 0                  49.7               18.6                195.0
# 1                  53.5               19.9                205.0
# 2                  50.0               19.5                196.0
# 3                  47.0               17.3                185.0
# 4                  49.7               18.6                195.0
# ..                  ...                ...                  ...
# 201                43.2               19.0                197.0
# 202                38.2               18.1                185.0
# 203                35.9               19.2                189.0
# 204                36.3               19.5                190.0
# 205                36.3               19.5                190.0
#
#      body_mass_g_y   sex_y
# 0           3600.0    MALE
# 1           4500.0    MALE
# 2           3900.0    MALE
# 3           3700.0  FEMALE
# 4           3600.0    MALE
# ..             ...     ...
# 201         4775.0    MALE
# 202         3950.0    MALE
# 203         3800.0  FEMALE
# 204         3800.0    MALE
# 205         3800.0    MALE
#
# [206 rows x 13 columns]

# %% [markdown]
# ### *Outer Join*

# %% [markdown]
# Outer join merupakan penggabungan semua *rows* atau baris ang tidak memiliki pasangan di kedua dataframe, jika *rows* tidak memiliki pasangan, di dataframe yang ingin digabungkan berdasarkan key column, maka kita tidak akan kehilangan baris seperti pada inner join, maka row akan ada pada merged dataframe dengan NaN values

# %%
Outer_merged = pd.merge(data1, data2, how="outer", on= ['species','island'])

# %%
Outer_merged
# Out:
#        species  island  culmen_length_mm_x  culmen_depth_mm_x  \
# 0    Chinstrap   Dream                45.5               17.0
# 1    Chinstrap   Dream                45.5               17.0
# 2    Chinstrap   Dream                45.5               17.0
# 3    Chinstrap   Dream                45.5               17.0
# 4    Chinstrap   Dream                46.1               18.2
# ..         ...     ...                 ...                ...
# 201     Adelie  Biscoe                42.0               19.5
# 202     Adelie  Biscoe                42.0               19.5
# 203     Adelie  Biscoe                42.0               19.5
# 204     Adelie   Dream                36.8               18.5
# 205     Adelie   Dream                39.2               21.1
#
#      flipper_length_mm_x  body_mass_g_x   sex_x  cummulative  \
# 0                  196.0         3500.0  FEMALE    11.529412
# 1                  196.0         3500.0  FEMALE    11.529412
# 2                  196.0         3500.0  FEMALE    11.529412
# 3                  196.0         3500.0  FEMALE    11.529412
# 4                  178.0         3250.0  FEMALE     9.780220
# ..                   ...            ...     ...          ...
# 201                200.0         4050.0    MALE    10.256410
# 202                200.0         4050.0    MALE    10.256410
# 203                200.0         4050.0    MALE    10.256410
# 204                193.0         3500.0  FEMALE    10.432432
# 205                196.0         4150.0    MALE     9.289100
#
#      culmen_length_mm_y  culmen_depth_mm_y  flipper_length_mm_y  \
# 0                  49.7               18.6                195.0
# 1                  53.5               19.9                205.0
# 2                  50.0               19.5                196.0
# 3                  47.0               17.3                185.0
# 4                  49.7               18.6                195.0
# ..                  ...                ...                  ...
# 201                43.2               19.0                197.0
# 202                38.2               18.1                185.0
# 203                35.9               19.2                189.0
# 204                36.3               19.5                190.0
# 205                36.3               19.5                190.0
#
#      body_mass_g_y   sex_y
# 0           3600.0    MALE
# 1           4500.0    MALE
# 2           3900.0    MALE
# 3           3700.0  FEMALE
# 4           3600.0    MALE
# ..             ...     ...
# 201         4775.0    MALE
# 202         3950.0    MALE
# 203         3800.0  FEMALE
# 204         3800.0    MALE
# 205         3800.0    MALE
#
# [206 rows x 13 columns]

# %% [markdown]
# ### *Left Join*

# %% [markdown]
# Left join atau juga bisa disebut $Left Outer Join$ merupakan penggabungan dataframe dengan mempertahankan semua *rows* yang ada pada dataframe di kiri tetapi melihat match value dengan data yang ada di kanan

# %%
left_merged = pd.merge(data1, data2, how="left", on= ['species','island'])
left_merged.shape
# Out:
# (206, 13)

# %%
left_merged
# Out:
#        species  island  culmen_length_mm_x  culmen_depth_mm_x  \
# 0    Chinstrap   Dream                45.5               17.0
# 1    Chinstrap   Dream                45.5               17.0
# 2    Chinstrap   Dream                45.5               17.0
# 3    Chinstrap   Dream                45.5               17.0
# 4    Chinstrap   Dream                46.1               18.2
# ..         ...     ...                 ...                ...
# 201     Adelie  Biscoe                42.0               19.5
# 202     Adelie  Biscoe                42.0               19.5
# 203     Adelie  Biscoe                42.0               19.5
# 204     Adelie  Biscoe                42.0               19.5
# 205     Adelie  Biscoe                42.0               19.5
#
#      flipper_length_mm_x  body_mass_g_x   sex_x  cummulative  \
# 0                  196.0         3500.0  FEMALE    11.529412
# 1                  196.0         3500.0  FEMALE    11.529412
# 2                  196.0         3500.0  FEMALE    11.529412
# 3                  196.0         3500.0  FEMALE    11.529412
# 4                  178.0         3250.0  FEMALE     9.780220
# ..                   ...            ...     ...          ...
# 201                200.0         4050.0    MALE    10.256410
# 202                200.0         4050.0    MALE    10.256410
# 203                200.0         4050.0    MALE    10.256410
# 204                200.0         4050.0    MALE    10.256410
# 205                200.0         4050.0    MALE    10.256410
#
#      culmen_length_mm_y  culmen_depth_mm_y  flipper_length_mm_y  \
# 0                  49.7               18.6                195.0
# 1                  53.5               19.9                205.0
# 2                  50.0               19.5                196.0
# 3                  47.0               17.3                185.0
# 4                  49.7               18.6                195.0
# ..                  ...                ...                  ...
# 201                42.0               19.5                200.0
# 202                35.7               16.9                185.0
# 203                43.2               19.0                197.0
# 204                38.2               18.1                185.0
# 205                35.9               19.2                189.0
#
#      body_mass_g_y   sex_y
# 0           3600.0    MALE
# 1           4500.0    MALE
# 2           3900.0    MALE
# 3           3700.0  FEMALE
# 4           3600.0    MALE
# ..             ...     ...
# 201         4050.0    MALE
# 202         3150.0  FEMALE
# 203         4775.0    MALE
# 204         3950.0    MALE
# 205         3800.0  FEMALE
#
# [206 rows x 13 columns]

# %% [markdown]
# ### *Right Join*

# %% [markdown]
# Right Outer join merupakan kebalikan dari left join dimana right outer join ini menggabungkan dataframe dengan mempertahankan value pada dataframe di kanan

# %%
right_merged = pd.merge(data1, data2, how="right", on= ['species','island'])
right_merged.shape
# Out:
# (206, 13)

# %%
right_merged
# Out:
#     species  island  culmen_length_mm_x  culmen_depth_mm_x  \
# 0    Gentoo  Biscoe                45.1               14.5
# 1    Gentoo  Biscoe                45.5               13.7
# 2    Gentoo  Biscoe                48.7               15.1
# 3    Gentoo  Biscoe                53.4               15.8
# 4    Gentoo  Biscoe                50.0               15.3
# ..      ...     ...                 ...                ...
# 201  Gentoo  Biscoe                44.9               13.8
# 202  Gentoo  Biscoe                45.7               13.9
# 203  Gentoo  Biscoe                49.2               15.2
# 204  Gentoo  Biscoe                47.8               15.0
# 205  Gentoo  Biscoe                46.6               14.2
#
#      flipper_length_mm_x  body_mass_g_x   sex_x  cummulative  \
# 0                  215.0         5000.0  FEMALE    14.827586
# 1                  214.0         4650.0  FEMALE    15.620438
# 2                  222.0         5350.0    MALE    14.701987
# 3                  219.0         5500.0    MALE    13.860759
# 4                  220.0         5550.0    MALE    14.379085
# ..                   ...            ...     ...          ...
# 201                212.0         4750.0  FEMALE    15.362319
# 202                214.0         4400.0  FEMALE    15.395683
# 203                221.0         6300.0    MALE    14.539474
# 204                215.0         5650.0    MALE    14.333333
# 205                210.0         4850.0  FEMALE    14.788732
#
#      culmen_length_mm_y  culmen_depth_mm_y  flipper_length_mm_y  \
# 0                  50.8               17.3                228.0
# 1                  50.8               17.3                228.0
# 2                  50.8               17.3                228.0
# 3                  50.8               17.3                228.0
# 4                  50.8               17.3                228.0
# ..                  ...                ...                  ...
# 201                44.5               14.3                216.0
# 202                44.5               14.3                216.0
# 203                44.5               14.3                216.0
# 204                44.5               14.3                216.0
# 205                44.5               14.3                216.0
#
#      body_mass_g_y sex_y
# 0           5600.0  MALE
# 1           5600.0  MALE
# 2           5600.0  MALE
# 3           5600.0  MALE
# 4           5600.0  MALE
# ..             ...   ...
# 201         4100.0   NaN
# 202         4100.0   NaN
# 203         4100.0   NaN
# 204         4100.0   NaN
# 205         4100.0   NaN
#
# [206 rows x 13 columns]

# %% [markdown]
# ## Join

# %% [markdown]
# jika ingin menggabungkan columns seperti $merge()$ kita harus set the columns sebagai indices.

# %%
inner_merged_total = pd.merge(data1, data2, on= ['species','island'])
print(inner_merged_total.shape)

inner_joined_total = data1.join(data2.set_index(['species','island']), 
                    on=['species','island'],
                    how="inner",
                    lsuffix="_x",
                    rsuffix="_y")
print(inner_joined_total.shape)
# Out:
# (206, 13)
# (206, 13)

# %% [markdown]
# ## Concat

# %% [markdown]
# untuk menggabungkan rows ataupun columns

# %% [markdown]
# ### Menggabungkan $Rows$

# %%
concatenated = pd.concat([data1, data2])
concatenated
# Out:
#        species     island  culmen_length_mm  culmen_depth_mm  \
# 195  Chinstrap      Dream              45.5             17.0
# 158  Chinstrap      Dream              46.1             18.2
# 241     Gentoo     Biscoe              45.1             14.5
# 3       Adelie  Torgersen               NaN              NaN
# 106     Adelie     Biscoe              38.6             17.2
# 232     Gentoo     Biscoe              45.5             13.7
# 239     Gentoo     Biscoe              48.7             15.1
# 176  Chinstrap      Dream              46.7             17.9
# 74      Adelie  Torgersen              35.5             17.5
# 13      Adelie  Torgersen              38.6             21.2
# 327     Gentoo     Biscoe              53.4             15.8
# 10      Adelie  Torgersen              37.8             17.1
# 249     Gentoo     Biscoe              50.0             15.3
# 59      Adelie     Biscoe              37.6             19.1
# 22      Adelie     Biscoe              35.9             19.2
# 132     Adelie      Dream              36.8             18.5
# 111     Adelie     Biscoe              45.6             20.3
# 294     Gentoo     Biscoe              46.4             15.0
# 60      Adelie     Biscoe              35.7             16.9
# 271     Gentoo     Biscoe              48.5             14.1
# 154  Chinstrap      Dream              51.3             19.2
# 339     Gentoo     Biscoe               NaN              NaN
# 224     Gentoo     Biscoe              47.6             14.5
# 227     Gentoo     Biscoe              46.7             15.3
# 101     Adelie     Biscoe              41.0             20.0
# 76      Adelie  Torgersen              40.9             16.8
# 304     Gentoo     Biscoe              44.9             13.8
# 21      Adelie     Biscoe              37.7             18.7
# 120     Adelie  Torgersen              36.2             17.2
# 35      Adelie      Dream              39.2             21.1
# 282     Gentoo     Biscoe              45.7             13.9
# 237     Gentoo     Biscoe              49.2             15.2
# 207  Chinstrap      Dream              52.2             18.8
# 192  Chinstrap      Dream              49.0             19.5
# 12      Adelie  Torgersen              41.1             17.6
# 129     Adelie  Torgersen              44.1             18.0
# 247     Gentoo     Biscoe              47.8             15.0
# 198  Chinstrap      Dream              50.1             17.9
# 270     Gentoo     Biscoe              46.6             14.2
# 53      Adelie     Biscoe              42.0             19.5
# 305     Gentoo     Biscoe              50.8             17.3
# 86      Adelie      Dream              36.3             19.5
# 53      Adelie     Biscoe              42.0             19.5
# 186  Chinstrap      Dream              49.7             18.6
# 286     Gentoo     Biscoe              46.2             14.4
# 60      Adelie     Biscoe              35.7             16.9
# 123     Adelie  Torgersen              41.4             18.5
# 119     Adelie  Torgersen              41.1             18.6
# 191  Chinstrap      Dream              53.5             19.9
# 109     Adelie     Biscoe              43.2             19.0
# 153  Chinstrap      Dream              50.0             19.5
# 267     Gentoo     Biscoe              50.5             15.9
# 23      Adelie     Biscoe              38.2             18.1
# 300     Gentoo     Biscoe              49.1             14.5
# 164  Chinstrap      Dream              47.0             17.3
# 22      Adelie     Biscoe              35.9             19.2
# 321     Gentoo     Biscoe              55.9             17.0
# 326     Gentoo     Biscoe              41.7             14.7
# 245     Gentoo     Biscoe              46.1             15.1
# 246     Gentoo     Biscoe              44.5             14.3
#
#      flipper_length_mm  body_mass_g     sex  cummulative
# 195              196.0       3500.0  FEMALE    11.529412
# 158              178.0       3250.0  FEMALE     9.780220
# 241              215.0       5000.0  FEMALE    14.827586
# 3                  NaN          NaN     NaN          NaN
# 106              199.0       3750.0  FEMALE    11.569767
# 232              214.0       4650.0  FEMALE    15.620438
# 239              222.0       5350.0    MALE    14.701987
# 176              195.0       3300.0  FEMALE    10.893855
# 74               190.0       3700.0  FEMALE    10.857143
# 13               191.0       3800.0    MALE     9.009434
# 327              219.0       5500.0    MALE    13.860759
# 10               186.0       3300.0     NaN    10.877193
# 249              220.0       5550.0    MALE    14.379085
# 59               194.0       3750.0    MALE    10.157068
# 22               189.0       3800.0  FEMALE     9.843750
# 132              193.0       3500.0  FEMALE    10.432432
# 111              191.0       4600.0    MALE     9.408867
# 294              216.0       4700.0  FEMALE    14.400000
# 60               185.0       3150.0  FEMALE    10.946746
# 271              220.0       5300.0    MALE    15.602837
# 154              193.0       3650.0    MALE    10.052083
# 339                NaN          NaN     NaN          NaN
# 224              215.0       5400.0    MALE    14.827586
# 227              219.0       5200.0    MALE    14.313725
# 101              203.0       4725.0    MALE    10.150000
# 76               191.0       3700.0  FEMALE    11.369048
# 304              212.0       4750.0  FEMALE    15.362319
# 21               180.0       3600.0    MALE     9.625668
# 120              187.0       3150.0  FEMALE    10.872093
# 35               196.0       4150.0    MALE     9.289100
# 282              214.0       4400.0  FEMALE    15.395683
# 237              221.0       6300.0    MALE    14.539474
# 207              197.0       3450.0    MALE    10.478723
# 192              210.0       3950.0    MALE    10.769231
# 12               182.0       3200.0  FEMALE    10.340909
# 129              210.0       4000.0    MALE    11.666667
# 247              215.0       5650.0    MALE    14.333333
# 198              190.0       3400.0  FEMALE    10.614525
# 270              210.0       4850.0  FEMALE    14.788732
# 53               200.0       4050.0    MALE    10.256410
# 305              228.0       5600.0    MALE          NaN
# 86               190.0       3800.0    MALE          NaN
# 53               200.0       4050.0    MALE          NaN
# 186              195.0       3600.0    MALE          NaN
# 286              214.0       4650.0     NaN          NaN
# 60               185.0       3150.0  FEMALE          NaN
# 123              202.0       3875.0    MALE          NaN
# 119              189.0       3325.0    MALE          NaN
# 191              205.0       4500.0    MALE          NaN
# 109              197.0       4775.0    MALE          NaN
# 153              196.0       3900.0    MALE          NaN
# 267              225.0       5400.0    MALE          NaN
# 23               185.0       3950.0    MALE          NaN
# 300              212.0       4625.0  FEMALE          NaN
# 164              185.0       3700.0  FEMALE          NaN
# 22               189.0       3800.0  FEMALE          NaN
# 321              228.0       5600.0    MALE          NaN
# 326              210.0       4700.0  FEMALE          NaN
# 245              215.0       5100.0    MALE          NaN
# 246              216.0       4100.0     NaN          NaN

# %% [markdown]
# ### Menggabungkan $Columns$

# %%
concatenated = pd.concat([data1, data2], axis="columns")
concatenated
# Out:
#        species     island  culmen_length_mm  culmen_depth_mm  \
# 195  Chinstrap      Dream              45.5             17.0
# 158  Chinstrap      Dream              46.1             18.2
# 241     Gentoo     Biscoe              45.1             14.5
# 3       Adelie  Torgersen               NaN              NaN
# 106     Adelie     Biscoe              38.6             17.2
# 232     Gentoo     Biscoe              45.5             13.7
# 239     Gentoo     Biscoe              48.7             15.1
# 176  Chinstrap      Dream              46.7             17.9
# 74      Adelie  Torgersen              35.5             17.5
# 13      Adelie  Torgersen              38.6             21.2
# 327     Gentoo     Biscoe              53.4             15.8
# 10      Adelie  Torgersen              37.8             17.1
# 249     Gentoo     Biscoe              50.0             15.3
# 59      Adelie     Biscoe              37.6             19.1
# 22      Adelie     Biscoe              35.9             19.2
# 132     Adelie      Dream              36.8             18.5
# 111     Adelie     Biscoe              45.6             20.3
# 294     Gentoo     Biscoe              46.4             15.0
# 60      Adelie     Biscoe              35.7             16.9
# 271     Gentoo     Biscoe              48.5             14.1
# 154  Chinstrap      Dream              51.3             19.2
# 339     Gentoo     Biscoe               NaN              NaN
# 224     Gentoo     Biscoe              47.6             14.5
# 227     Gentoo     Biscoe              46.7             15.3
# 101     Adelie     Biscoe              41.0             20.0
# 76      Adelie  Torgersen              40.9             16.8
# 304     Gentoo     Biscoe              44.9             13.8
# 21      Adelie     Biscoe              37.7             18.7
# 120     Adelie  Torgersen              36.2             17.2
# 35      Adelie      Dream              39.2             21.1
# 282     Gentoo     Biscoe              45.7             13.9
# 237     Gentoo     Biscoe              49.2             15.2
# 207  Chinstrap      Dream              52.2             18.8
# 192  Chinstrap      Dream              49.0             19.5
# 12      Adelie  Torgersen              41.1             17.6
# 129     Adelie  Torgersen              44.1             18.0
# 247     Gentoo     Biscoe              47.8             15.0
# 198  Chinstrap      Dream              50.1             17.9
# 270     Gentoo     Biscoe              46.6             14.2
# 53      Adelie     Biscoe              42.0             19.5
# 305        NaN        NaN               NaN              NaN
# 86         NaN        NaN               NaN              NaN
# 186        NaN        NaN               NaN              NaN
# 286        NaN        NaN               NaN              NaN
# 123        NaN        NaN               NaN              NaN
# 119        NaN        NaN               NaN              NaN
# 191        NaN        NaN               NaN              NaN
# 109        NaN        NaN               NaN              NaN
# 153        NaN        NaN               NaN              NaN
# 267        NaN        NaN               NaN              NaN
# 23         NaN        NaN               NaN              NaN
# 300        NaN        NaN               NaN              NaN
# 164        NaN        NaN               NaN              NaN
# 321        NaN        NaN               NaN              NaN
# 326        NaN        NaN               NaN              NaN
# 245        NaN        NaN               NaN              NaN
# 246        NaN        NaN               NaN              NaN
#
#      flipper_length_mm  body_mass_g     sex  cummulative    species  \
# 195              196.0       3500.0  FEMALE    11.529412        NaN
# 158              178.0       3250.0  FEMALE     9.780220        NaN
# 241              215.0       5000.0  FEMALE    14.827586        NaN
# 3                  NaN          NaN     NaN          NaN        NaN
# 106              199.0       3750.0  FEMALE    11.569767        NaN
# 232              214.0       4650.0  FEMALE    15.620438        NaN
# 239              222.0       5350.0    MALE    14.701987        NaN
# 176              195.0       3300.0  FEMALE    10.893855        NaN
# 74               190.0       3700.0  FEMALE    10.857143        NaN
# 13               191.0       3800.0    MALE     9.009434        NaN
# 327              219.0       5500.0    MALE    13.860759        NaN
# 10               186.0       3300.0     NaN    10.877193        NaN
# 249              220.0       5550.0    MALE    14.379085        NaN
# 59               194.0       3750.0    MALE    10.157068        NaN
# 22               189.0       3800.0  FEMALE     9.843750     Adelie
# 132              193.0       3500.0  FEMALE    10.432432        NaN
# 111              191.0       4600.0    MALE     9.408867        NaN
# 294              216.0       4700.0  FEMALE    14.400000        NaN
# 60               185.0       3150.0  FEMALE    10.946746     Adelie
# 271              220.0       5300.0    MALE    15.602837        NaN
# 154              193.0       3650.0    MALE    10.052083        NaN
# 339                NaN          NaN     NaN          NaN        NaN
# 224              215.0       5400.0    MALE    14.827586        NaN
# 227              219.0       5200.0    MALE    14.313725        NaN
# 101              203.0       4725.0    MALE    10.150000        NaN
# 76               191.0       3700.0  FEMALE    11.369048        NaN
# 304              212.0       4750.0  FEMALE    15.362319        NaN
# 21               180.0       3600.0    MALE     9.625668        NaN
# 120              187.0       3150.0  FEMALE    10.872093        NaN
# 35               196.0       4150.0    MALE     9.289100        NaN
# 282              214.0       4400.0  FEMALE    15.395683        NaN
# 237              221.0       6300.0    MALE    14.539474        NaN
# 207              197.0       3450.0    MALE    10.478723        NaN
# 192              210.0       3950.0    MALE    10.769231        NaN
# 12               182.0       3200.0  FEMALE    10.340909        NaN
# 129              210.0       4000.0    MALE    11.666667        NaN
# 247              215.0       5650.0    MALE    14.333333        NaN
# 198              190.0       3400.0  FEMALE    10.614525        NaN
# 270              210.0       4850.0  FEMALE    14.788732        NaN
# 53               200.0       4050.0    MALE    10.256410     Adelie
# 305                NaN          NaN     NaN          NaN     Gentoo
# 86                 NaN          NaN     NaN          NaN     Adelie
# 186                NaN          NaN     NaN          NaN  Chinstrap
# 286                NaN          NaN     NaN          NaN     Gentoo
# 123                NaN          NaN     NaN          NaN     Adelie
# 119                NaN          NaN     NaN          NaN     Adelie
# 191                NaN          NaN     NaN          NaN  Chinstrap
# 109                NaN          NaN     NaN          NaN     Adelie
# 153                NaN          NaN     NaN          NaN  Chinstrap
# 267                NaN          NaN     NaN          NaN     Gentoo
# 23                 NaN          NaN     NaN          NaN     Adelie
# 300                NaN          NaN     NaN          NaN     Gentoo
# 164                NaN          NaN     NaN          NaN  Chinstrap
# 321                NaN          NaN     NaN          NaN     Gentoo
# 326                NaN          NaN     NaN          NaN     Gentoo
# 245                NaN          NaN     NaN          NaN     Gentoo
# 246                NaN          NaN     NaN          NaN     Gentoo
#
#         island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 195        NaN               NaN              NaN                NaN
# 158        NaN               NaN              NaN                NaN
# 241        NaN               NaN              NaN                NaN
# 3          NaN               NaN              NaN                NaN
# 106        NaN               NaN              NaN                NaN
# 232        NaN               NaN              NaN                NaN
# 239        NaN               NaN              NaN                NaN
# 176        NaN               NaN              NaN                NaN
# 74         NaN               NaN              NaN                NaN
# 13         NaN               NaN              NaN                NaN
# 327        NaN               NaN              NaN                NaN
# 10         NaN               NaN              NaN                NaN
# 249        NaN               NaN              NaN                NaN
# 59         NaN               NaN              NaN                NaN
# 22      Biscoe              35.9             19.2              189.0
# 132        NaN               NaN              NaN                NaN
# 111        NaN               NaN              NaN                NaN
# 294        NaN               NaN              NaN                NaN
# 60      Biscoe              35.7             16.9              185.0
# 271        NaN               NaN              NaN                NaN
# 154        NaN               NaN              NaN                NaN
# 339        NaN               NaN              NaN                NaN
# 224        NaN               NaN              NaN                NaN
# 227        NaN               NaN              NaN                NaN
# 101        NaN               NaN              NaN                NaN
# 76         NaN               NaN              NaN                NaN
# 304        NaN               NaN              NaN                NaN
# 21         NaN               NaN              NaN                NaN
# 120        NaN               NaN              NaN                NaN
# 35         NaN               NaN              NaN                NaN
# 282        NaN               NaN              NaN                NaN
# 237        NaN               NaN              NaN                NaN
# 207        NaN               NaN              NaN                NaN
# 192        NaN               NaN              NaN                NaN
# 12         NaN               NaN              NaN                NaN
# 129        NaN               NaN              NaN                NaN
# 247        NaN               NaN              NaN                NaN
# 198        NaN               NaN              NaN                NaN
# 270        NaN               NaN              NaN                NaN
# 53      Biscoe              42.0             19.5              200.0
# 305     Biscoe              50.8             17.3              228.0
# 86       Dream              36.3             19.5              190.0
# 186      Dream              49.7             18.6              195.0
# 286     Biscoe              46.2             14.4              214.0
# 123  Torgersen              41.4             18.5              202.0
# 119  Torgersen              41.1             18.6              189.0
# 191      Dream              53.5             19.9              205.0
# 109     Biscoe              43.2             19.0              197.0
# 153      Dream              50.0             19.5              196.0
# 267     Biscoe              50.5             15.9              225.0
# 23      Biscoe              38.2             18.1              185.0
# 300     Biscoe              49.1             14.5              212.0
# 164      Dream              47.0             17.3              185.0
# 321     Biscoe              55.9             17.0              228.0
# 326     Biscoe              41.7             14.7              210.0
# 245     Biscoe              46.1             15.1              215.0
# 246     Biscoe              44.5             14.3              216.0
#
#      body_mass_g     sex
# 195          NaN     NaN
# 158          NaN     NaN
# 241          NaN     NaN
# 3            NaN     NaN
# 106          NaN     NaN
# 232          NaN     NaN
# 239          NaN     NaN
# 176          NaN     NaN
# 74           NaN     NaN
# 13           NaN     NaN
# 327          NaN     NaN
# 10           NaN     NaN
# 249          NaN     NaN
# 59           NaN     NaN
# 22        3800.0  FEMALE
# 132          NaN     NaN
# 111          NaN     NaN
# 294          NaN     NaN
# 60        3150.0  FEMALE
# 271          NaN     NaN
# 154          NaN     NaN
# 339          NaN     NaN
# 224          NaN     NaN
# 227          NaN     NaN
# 101          NaN     NaN
# 76           NaN     NaN
# 304          NaN     NaN
# 21           NaN     NaN
# 120          NaN     NaN
# 35           NaN     NaN
# 282          NaN     NaN
# 237          NaN     NaN
# 207          NaN     NaN
# 192          NaN     NaN
# 12           NaN     NaN
# 129          NaN     NaN
# 247          NaN     NaN
# 198          NaN     NaN
# 270          NaN     NaN
# 53        4050.0    MALE
# 305       5600.0    MALE
# 86        3800.0    MALE
# 186       3600.0    MALE
# 286       4650.0     NaN
# 123       3875.0    MALE
# 119       3325.0    MALE
# 191       4500.0    MALE
# 109       4775.0    MALE
# 153       3900.0    MALE
# 267       5400.0    MALE
# 23        3950.0    MALE
# 300       4625.0  FEMALE
# 164       3700.0  FEMALE
# 321       5600.0    MALE
# 326       4700.0  FEMALE
# 245       5100.0    MALE
# 246       4100.0     NaN

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# Data visualization mengubah kumpulan data menjadi hal lebih sederhana untuk ditampilkan.
#
# Dengan menggunakan elemen visual tersebut, pembaca akan lebih mudah memahami tren, outliers, dan pola dalam suatu data.
#
# Dalam bisnis, data visualization memungkinkan para pembuat keputusan untuk melihat analitik yang disajikan secara visual.
#
# Dengan begitu, mereka dapat memahami konsep yang sulit atau mengidentifikasi pola baru. Hal ini akan membuat pengambilan keputusan menjadi lebih mudah dan tepat.

# %% [markdown]
# ## Visualisasi Data dengan Python (Seaborn dan Matplotlib)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
data = pd.read_csv("penguins_size.csv")

# %%
data.head(5)
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
#drop data yang NA
data.dropna(inplace=True)

# %%
data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        334.000000       334.000000         334.000000   334.000000
# mean          43.994311        17.160479         201.014970  4209.056886
# std            5.460521         1.967909          14.022175   804.836129
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.500000        15.600000         190.000000  3550.000000
# 50%           44.500000        17.300000         197.000000  4050.000000
# 75%           48.575000        18.700000         213.000000  4793.750000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# ### Line Plot

# %%
dowjones = sns.load_dataset("dowjones")
dowjones
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
dowjones['Date'] = pd.to_datetime(dowjones['Date'], format = '%Y-%m-%d')
sns.relplot(data=dowjones, x="Date", y="Price", kind="line")

# %% [markdown]
# (Interpretasi)

# %% [markdown]
# ### Barplot

# %%
sns.barplot(x='species',y='body_mass_g',data=data)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %% [markdown]
# (Interpretasi)

# %% [markdown]
# ### Countplot

# %%
sns.countplot(df[''])

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x="species",y="culmen_length_mm",data=data)
# Out:
# <Axes: xlabel='species', ylabel='culmen_length_mm'>

# %% [markdown]
# (Interpretasi)

# %% [markdown]
# ### Pie Plot

# %%
valpie = data.species.value_counts().values
labelpie = data.species.unique().tolist()
explode = [0.05,0.01,0.01]
plt.pie(valpie, labels=labelpie,explode=explode)
plt.show()

# %% [markdown]
# (Interpretasi)

# %% [markdown]
# ### Violinplot

# %%
sns.violinplot(x="species",y="culmen_depth_mm",data=data)
# Out:
# <Axes: xlabel='species', ylabel='culmen_depth_mm'>

# %% [markdown]
# (Interpretasi)

# %% [markdown]
# ### Heatmap

# %%
data.corr()
# Out:
# C:\Users\Raditya Arviandana\AppData\Local\Temp\ipykernel_5636\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.228640           0.652126
# culmen_depth_mm           -0.228640         1.000000          -0.578730
# flipper_length_mm          0.652126        -0.578730           1.000000
# body_mass_g                0.589066        -0.472987           0.873211
#
#                    body_mass_g
# culmen_length_mm      0.589066
# culmen_depth_mm      -0.472987
# flipper_length_mm     0.873211
# body_mass_g           1.000000

# %%
sns.heatmap(data.corr(),cmap='coolwarm',annot=True,linecolor='white',linewidths=1)
# Out:
# C:\Users\Raditya Arviandana\AppData\Local\Temp\ipykernel_5636\3117699093.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),cmap='coolwarm',annot=True,linecolor='white',linewidths=1)
# <Axes: >

# %% [markdown]
# (Interpretasi)

# %% [markdown]
# ### Distribution Plot

# %%
sns.displot(data['culmen_length_mm'], kind = 'hist', kde = True)

# %% [markdown]
# (Interpretasi)

# %% [markdown]
# ### Joint Plot

# %% [markdown]
# jointplot() daapt digunakan untuk mencocokkan dua distplot untuk data bivariat.
#
# Parameter 'kind' yang dapat digunakan yaitu:
# - “scatter”
# - “reg”
# - “resid”
# - “kde”
# - “hex”

# %% [markdown]
# Dengan garis regresi

# %%
sns.jointplot(x='flipper_length_mm',y='body_mass_g',data = data,kind = 'reg')

# %% [markdown]
# (Interpretasi)

# %% [markdown]
# Tidak menggunakan garis regresi

# %%
sns.jointplot(x='flipper_length_mm',y='body_mass_g',data = data,kind = 'scatter')

# %% [markdown]
# (Interpretasi)

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue="species")

# %% [markdown]
# (Interpretasi)
